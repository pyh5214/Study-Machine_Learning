# %% [markdown]
# # LightGBM

# %% [markdown]
# ## LightGBM 장단점
#
# - XGB보다도 학습에 걸리는 시간이 훨씬 적으며 메모리 사용량도 상대적으로 적다
# - 카테고리형 피처를 자동 변환하고, 예측 성능 역시 XGB와 큰 차이가 없다.
# - 데이터의 갯수가 적을 경우 과적합이 발생하기 쉽다.
# - 적은 데이터의 갯수에 대한 기준은 애매하지만 LightGBM의 공식문서에서 10,000건 이하라고 기술하였다.

# %% [markdown]
# ## 트리 기반 알고리즘 특징
#
# - 기존의 대부분 트리 기반 알고리즘은 트리의 깊이를 효과적으로 줄이기 위한 균형 트리 분할(Level Wise) 방식을 사용한다.
# - 최대한 균형 잡힌 트리를 유지하면서 분할하기 때문에 깊이가 최소화되며 과대적합에 보다 강한 구조를 가진다.

# %% [markdown]
# ## LightGBM 특징
#
# - LightGBM은 일반 GBM 계열의 트리 분할 방법과 다르게 리프 중심 트리 분할(Leaf Wise) 방식을 사용한다.
# - 트리의 균형을 맞추지 않고 최대 손실값(max delta loss)을 가지는 리프 노드를 지속적으로 분할하여 깊이가 증가하고 비대칭적인 트리를 생성한다.
# - 이렇게 생성된 트리는 학습을 반복할수록 결국은 균형 트리 분할 장식보다 예측 오류 손실을 최소화 활 수 있다는 것이 LightGBM의 구현 사상이다.

# %% [markdown]
# # 필수라이브러리

# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
from IPython.display import Image

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

mpl.rc('font', family = 'D2coding')
mpl.rc('axes', unicode_minus = False)

sns.set_style('darkgrid')
plt.rc('figure', figsize = (10, 8))

warnings.filterwarnings('ignore')

# %% [markdown]
# # 데이터 로딩과 훈련세트와 테스트세트 분리

# %%
from lightgbm import LGBMClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
X, y = load_breast_cancer(True)

print(X.shape)
print(y.shape)
# Out:
# (569, 30)
# (569,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 156)

# %%
evals = [(X_test, y_test)]

# 학습
lgbm = LGBMClassifier(n_estimators = 4000)
lgbm.fit(X_train, y_train, early_stopping_rounds = 100, eval_metric = 'logloss',
        eval_set = evals, verbose = True)
# Out:
# [1]	valid_0's binary_logloss: 0.565079
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's binary_logloss: 0.507451
# [3]	valid_0's binary_logloss: 0.458489
# [4]	valid_0's binary_logloss: 0.417481
# [5]	valid_0's binary_logloss: 0.385507
# [6]	valid_0's binary_logloss: 0.355773
# [7]	valid_0's binary_logloss: 0.329587
# [8]	valid_0's binary_logloss: 0.308478
# [9]	valid_0's binary_logloss: 0.285395
# [10]	valid_0's binary_logloss: 0.267055
# [11]	valid_0's binary_logloss: 0.252013
# [12]	valid_0's binary_logloss: 0.237018
# [13]	valid_0's binary_logloss: 0.224756
# [14]	valid_0's binary_logloss: 0.213383
# [15]	valid_0's binary_logloss: 0.203058
# [16]	valid_0's binary_logloss: 0.194015
# [17]	valid_0's binary_logloss: 0.186412
# [18]	valid_0's binary_logloss: 0.179108
# [19]	valid_0's binary_logloss: 0.174004
# [20]	valid_0's binary_logloss: 0.167155
# [21]	valid_0's binary_logloss: 0.162494
# [22]	valid_0's binary_logloss: 0.156886
# [23]	valid_0's binary_logloss: 0.152855
# [24]	valid_0's binary_logloss: 0.151113
# [25]	valid_0's binary_logloss: 0.148395
# [26]	valid_0's binary_logloss: 0.145869
# [27]	valid_0's binary_logloss: 0.143036
# [28]	valid_0's binary_logloss: 0.14033
# [29]	valid_0's binary_logloss: 0.139609
# [30]	valid_0's binary_logloss: 0.136109
# [31]	valid_0's binary_logloss: 0.134867
# [32]	valid_0's binary_logloss: 0.134729
# [33]	valid_0's binary_logloss: 0.1311
# [34]	valid_0's binary_logloss: 0.131143
# [35]	valid_0's binary_logloss: 0.129435
# [36]	valid_0's binary_logloss: 0.128474
# [37]	valid_0's binary_logloss: 0.126683
# [38]	valid_0's binary_logloss: 0.126112
# [39]	valid_0's binary_logloss: 0.122831
# [40]	valid_0's binary_logloss: 0.123162
# [41]	valid_0's binary_logloss: 0.125592
# [42]	valid_0's binary_logloss: 0.128293
# [43]	valid_0's binary_logloss: 0.128123
# [44]	valid_0's binary_logloss: 0.12789
# [45]	valid_0's binary_logloss: 0.122818
# [46]	valid_0's binary_logloss: 0.12496
# [47]	valid_0's binary_logloss: 0.125578
# [48]	valid_0's binary_logloss: 0.127381
# [49]	valid_0's binary_logloss: 0.128349
# [50]	valid_0's binary_logloss: 0.127004
# [51]	valid_0's binary_logloss: 0.130288
# [52]	valid_0's binary_logloss: 0.131362
# [53]	valid_0's binary_logloss: 0.133363
# [54]	valid_0's binary_logloss: 0.1332
# [55]	valid_0's binary_logloss: 0.134543
# [56]	valid_0's binary_logloss: 0.130803
# [57]	valid_0's binary_logloss: 0.130306
# [58]	valid_0's binary_logloss: 0.132514
# [59]	valid_0's binary_logloss: 0.133278
# [60]	valid_0's binary_logloss: 0.134804
# [61]	valid_0's binary_logloss: 0.136888
# [62]	valid_0's binary_logloss: 0.138745
# [63]	valid_0's binary_logloss: 0.140497
# [64]	valid_0's binary_logloss: 0.141368
# [65]	valid_0's binary_logloss: 0.140764
# [66]	valid_0's binary_logloss: 0.14348
# [67]	valid_0's binary_logloss: 0.143418
# [68]	valid_0's binary_logloss: 0.143682
# [69]	valid_0's binary_logloss: 0.145076
# [70]	valid_0's binary_logloss: 0.14686
# [71]	valid_0's binary_logloss: 0.148051
# [72]	valid_0's binary_logloss: 0.147664
# [73]	valid_0's binary_logloss: 0.149478
# [74]	valid_0's binary_logloss: 0.14708
# [75]	valid_0's binary_logloss: 0.14545
# [76]	valid_0's binary_logloss: 0.148767
# [77]	valid_0's binary_logloss: 0.149959
# [78]	valid_0's binary_logloss: 0.146083
# [79]	valid_0's binary_logloss: 0.14638
# [80]	valid_0's binary_logloss: 0.148461
# [81]	valid_0's binary_logloss: 0.15091
# [82]	valid_0's binary_logloss: 0.153011
# [83]	valid_0's binary_logloss: 0.154807
# [84]	valid_0's binary_logloss: 0.156501
# [85]	valid_0's binary_logloss: 0.158586
# [86]	valid_0's binary_logloss: 0.159819
# [87]	valid_0's binary_logloss: 0.161745
# [88]	valid_0's binary_logloss: 0.162829
# [89]	valid_0's binary_logloss: 0.159142
# [90]	valid_0's binary_logloss: 0.156765
# [91]	valid_0's binary_logloss: 0.158625
# [92]	valid_0's binary_logloss: 0.156832
# [93]	valid_0's binary_logloss: 0.154616
# [94]	valid_0's binary_logloss: 0.154263
# [95]	valid_0's binary_logloss: 0.157156
# [96]	valid_0's binary_logloss: 0.158617
# [97]	valid_0's binary_logloss: 0.157495
# [98]	valid_0's binary_logloss: 0.159413
# [99]	valid_0's binary_logloss: 0.15847
# [100]	valid_0's binary_logloss: 0.160746
# [101]	valid_0's binary_logloss: 0.16217
# [102]	valid_0's binary_logloss: 0.165293
# [103]	valid_0's binary_logloss: 0.164749
# [104]	valid_0's binary_logloss: 0.167097
# [105]	valid_0's binary_logloss: 0.167697
# [106]	valid_0's binary_logloss: 0.169462
# [107]	valid_0's binary_logloss: 0.169947
# [108]	valid_0's binary_logloss: 0.171
# [109]	valid_0's binary_logloss: 0.16907
# [110]	valid_0's binary_logloss: 0.169521
# [111]	valid_0's binary_logloss: 0.167719
# [112]	valid_0's binary_logloss: 0.166648
# [113]	valid_0's binary_logloss: 0.169053
# [114]	valid_0's binary_logloss: 0.169613
# [115]	valid_0's binary_logloss: 0.170059
# [116]	valid_0's binary_logloss: 0.1723
# [117]	valid_0's binary_logloss: 0.174733
# [118]	valid_0's binary_logloss: 0.173526
# [119]	valid_0's binary_logloss: 0.1751
# [120]	valid_0's binary_logloss: 0.178254
# [121]	valid_0's binary_logloss: 0.182968
# [122]	valid_0's binary_logloss: 0.179017
# [123]	valid_0's binary_logloss: 0.178326
# [124]	valid_0's binary_logloss: 0.177149
# [125]	valid_0's binary_logloss: 0.179171
# [126]	valid_0's binary_logloss: 0.180948
# [127]	valid_0's binary_logloss: 0.183861
# [128]	valid_0's binary_logloss: 0.187579
# [129]	valid_0's binary_logloss: 0.188122
# [130]	valid_0's binary_logloss: 0.1857
# [131]	valid_0's binary_logloss: 0.187442
# [132]	valid_0's binary_logloss: 0.188578
# [133]	valid_0's binary_logloss: 0.189729
# [134]	valid_0's binary_logloss: 0.187313
# [135]	valid_0's binary_logloss: 0.189279
# [136]	valid_0's binary_logloss: 0.191068
# [137]	valid_0's binary_logloss: 0.192414
# [138]	valid_0's binary_logloss: 0.191255
# [139]	valid_0's binary_logloss: 0.193453
# [140]	valid_0's binary_logloss: 0.196969
# [141]	valid_0's binary_logloss: 0.196378
# [142]	valid_0's binary_logloss: 0.196367
# [143]	valid_0's binary_logloss: 0.19869
# [144]	valid_0's binary_logloss: 0.200352
# [145]	valid_0's binary_logloss: 0.19712
# Early stopping, best iteration is:
# [45]	valid_0's binary_logloss: 0.122818
# LGBMClassifier(n_estimators=4000)

# %%
def  get_clf_eval(y_test, pred=None, pred_proba=None):
    from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_auc_score
    
    confusion = confusion_matrix(y_test, pred)
    accuracy = accuracy_score(y_test, pred)
    precision = precision_score(y_test, pred)
    recall = recall_score(y_test, pred)
    f1 = f1_score(y_test, pred)
    roc_auc = roc_auc_score(y_test, pred_proba)
    
    print('오차 행렬')
    print(confusion)
 
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, \
    재현율: {2:.4f}, F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, roc_auc_score, f1_score

# %%
pred = lgbm.predict(X_test)

# %%
# pred_proba 생성
pred_proba_po = lgbm.predict_proba(X_test)[:, 1].reshape(-1, 1)

# %%
confusion = confusion_matrix(y_test, pred)
accuracy = accuracy_score(y_test, pred)
precision = precision_score(y_test, pred)
recall = recall_score(y_test, pred)
f1 = f1_score(y_test, pred)

print('오차 행렬')
print(confusion)

print('정확도: {0:.4f}, 정밀도: {1:.4f}, \
재현율: {2:.4f}, F1: {3:.4f}'.format(accuracy, precision, recall, f1))
# Out:
# 오차 행렬
# [[33  4]
#  [ 1 76]]
# 정확도: 0.9561, 정밀도: 0.9500, 재현율: 0.9870, F1: 0.9682

# %%
# 정확도
accuracy_score(y_test, pred)
# Out:
# 0.956140350877193

# %%
# 정밀도
precision = precision_score(y_test, pred)
precision
# Out:
# 0.95

# %%
# 재현율
recall = recall_score(y_test, pred)
recall
# Out:
# 0.987012987012987

# %%
# F1 score
f1 = f1_score(y_test, pred)
f1
# Out:
# 0.9681528662420381

# %%
evals = [(X_test, y_test)]

# 학습
lgbm = LGBMClassifier(n_estimators = 4000)
lgbm.fit(X_train, y_train, early_stopping_rounds = 100, eval_metric = 'logloss',
        eval_set = evals, verbose = True)
# Out:
# [1]	training's binary_logloss: 0.585834	valid_1's binary_logloss: 0.565079
# Training until validation scores don't improve for 100 rounds
# [2]	training's binary_logloss: 0.522733	valid_1's binary_logloss: 0.507451
# [3]	training's binary_logloss: 0.468843	valid_1's binary_logloss: 0.458489
# [4]	training's binary_logloss: 0.424905	valid_1's binary_logloss: 0.417481
# [5]	training's binary_logloss: 0.386683	valid_1's binary_logloss: 0.385507
# [6]	training's binary_logloss: 0.350279	valid_1's binary_logloss: 0.355773
# [7]	training's binary_logloss: 0.318714	valid_1's binary_logloss: 0.329587
# [8]	training's binary_logloss: 0.293358	valid_1's binary_logloss: 0.308478
# [9]	training's binary_logloss: 0.267737	valid_1's binary_logloss: 0.285395
# [10]	training's binary_logloss: 0.24655	valid_1's binary_logloss: 0.267055
# [11]	training's binary_logloss: 0.228594	valid_1's binary_logloss: 0.252013
# [12]	training's binary_logloss: 0.211667	valid_1's binary_logloss: 0.237018
# [13]	training's binary_logloss: 0.195683	valid_1's binary_logloss: 0.224756
# [14]	training's binary_logloss: 0.179633	valid_1's binary_logloss: 0.213383
# [15]	training's binary_logloss: 0.168219	valid_1's binary_logloss: 0.203058
# [16]	training's binary_logloss: 0.156917	valid_1's binary_logloss: 0.194015
# [17]	training's binary_logloss: 0.1449	valid_1's binary_logloss: 0.186412
# [18]	training's binary_logloss: 0.134808	valid_1's binary_logloss: 0.179108
# [19]	training's binary_logloss: 0.125107	valid_1's binary_logloss: 0.174004
# [20]	training's binary_logloss: 0.117093	valid_1's binary_logloss: 0.167155
# [21]	training's binary_logloss: 0.108428	valid_1's binary_logloss: 0.162494
# [22]	training's binary_logloss: 0.100525	valid_1's binary_logloss: 0.156886
# [23]	training's binary_logloss: 0.0937572	valid_1's binary_logloss: 0.152855
# [24]	training's binary_logloss: 0.0879404	valid_1's binary_logloss: 0.151113
# [25]	training's binary_logloss: 0.08099	valid_1's binary_logloss: 0.148395
# [26]	training's binary_logloss: 0.0747228	valid_1's binary_logloss: 0.145869
# [27]	training's binary_logloss: 0.069579	valid_1's binary_logloss: 0.143036
# [28]	training's binary_logloss: 0.0646296	valid_1's binary_logloss: 0.14033
# [29]	training's binary_logloss: 0.0602096	valid_1's binary_logloss: 0.139609
# [30]	training's binary_logloss: 0.0563757	valid_1's binary_logloss: 0.136109
# [31]	training's binary_logloss: 0.0525917	valid_1's binary_logloss: 0.134867
# [32]	training's binary_logloss: 0.0484813	valid_1's binary_logloss: 0.134729
# [33]	training's binary_logloss: 0.0455909	valid_1's binary_logloss: 0.1311
# [34]	training's binary_logloss: 0.04244	valid_1's binary_logloss: 0.131143
# [35]	training's binary_logloss: 0.039565	valid_1's binary_logloss: 0.129435
# [36]	training's binary_logloss: 0.0367461	valid_1's binary_logloss: 0.128474
# [37]	training's binary_logloss: 0.0346733	valid_1's binary_logloss: 0.126683
# [38]	training's binary_logloss: 0.032259	valid_1's binary_logloss: 0.126112
# [39]	training's binary_logloss: 0.0299677	valid_1's binary_logloss: 0.122831
# [40]	training's binary_logloss: 0.0276625	valid_1's binary_logloss: 0.123162
# [41]	training's binary_logloss: 0.0257507	valid_1's binary_logloss: 0.125592
# [42]	training's binary_logloss: 0.0241149	valid_1's binary_logloss: 0.128293
# [43]	training's binary_logloss: 0.0226124	valid_1's binary_logloss: 0.128123
# [44]	training's binary_logloss: 0.0211129	valid_1's binary_logloss: 0.12789
# [45]	training's binary_logloss: 0.0196658	valid_1's binary_logloss: 0.122818
# [46]	training's binary_logloss: 0.0185626	valid_1's binary_logloss: 0.12496
# [47]	training's binary_logloss: 0.0172853	valid_1's binary_logloss: 0.125578
# [48]	training's binary_logloss: 0.0161747	valid_1's binary_logloss: 0.127381
# [49]	training's binary_logloss: 0.0150804	valid_1's binary_logloss: 0.128349
# [50]	training's binary_logloss: 0.0140152	valid_1's binary_logloss: 0.127004
# [51]	training's binary_logloss: 0.013222	valid_1's binary_logloss: 0.130288
# [52]	training's binary_logloss: 0.0123613	valid_1's binary_logloss: 0.131362
# [53]	training's binary_logloss: 0.0115934	valid_1's binary_logloss: 0.133363
# [54]	training's binary_logloss: 0.0108261	valid_1's binary_logloss: 0.1332
# [55]	training's binary_logloss: 0.0102188	valid_1's binary_logloss: 0.134543
# [56]	training's binary_logloss: 0.00953532	valid_1's binary_logloss: 0.130803
# [57]	training's binary_logloss: 0.00870538	valid_1's binary_logloss: 0.130306
# [58]	training's binary_logloss: 0.0081693	valid_1's binary_logloss: 0.132514
# [59]	training's binary_logloss: 0.00751233	valid_1's binary_logloss: 0.133278
# [60]	training's binary_logloss: 0.00706122	valid_1's binary_logloss: 0.134804
# [61]	training's binary_logloss: 0.00666996	valid_1's binary_logloss: 0.136888
# [62]	training's binary_logloss: 0.00624439	valid_1's binary_logloss: 0.138745
# [63]	training's binary_logloss: 0.00586397	valid_1's binary_logloss: 0.140497
# [64]	training's binary_logloss: 0.00547422	valid_1's binary_logloss: 0.141368
# [65]	training's binary_logloss: 0.00513779	valid_1's binary_logloss: 0.140764
# [66]	training's binary_logloss: 0.00481616	valid_1's binary_logloss: 0.14348
# [67]	training's binary_logloss: 0.00453042	valid_1's binary_logloss: 0.143418
# [68]	training's binary_logloss: 0.00418068	valid_1's binary_logloss: 0.143682
# [69]	training's binary_logloss: 0.00387692	valid_1's binary_logloss: 0.145076
# [70]	training's binary_logloss: 0.00364646	valid_1's binary_logloss: 0.14686
# [71]	training's binary_logloss: 0.00336043	valid_1's binary_logloss: 0.148051
# [72]	training's binary_logloss: 0.00310397	valid_1's binary_logloss: 0.147664
# [73]	training's binary_logloss: 0.00292581	valid_1's binary_logloss: 0.149478
# [74]	training's binary_logloss: 0.00275536	valid_1's binary_logloss: 0.14708
# [75]	training's binary_logloss: 0.00255519	valid_1's binary_logloss: 0.14545
# [76]	training's binary_logloss: 0.00240981	valid_1's binary_logloss: 0.148767
# [77]	training's binary_logloss: 0.00222274	valid_1's binary_logloss: 0.149959
# [78]	training's binary_logloss: 0.00208628	valid_1's binary_logloss: 0.146083
# [79]	training's binary_logloss: 0.00197408	valid_1's binary_logloss: 0.14638
# [80]	training's binary_logloss: 0.00183671	valid_1's binary_logloss: 0.148461
# [81]	training's binary_logloss: 0.00171736	valid_1's binary_logloss: 0.15091
# [82]	training's binary_logloss: 0.00161959	valid_1's binary_logloss: 0.153011
# [83]	training's binary_logloss: 0.00151094	valid_1's binary_logloss: 0.154807
# [84]	training's binary_logloss: 0.00141019	valid_1's binary_logloss: 0.156501
# [85]	training's binary_logloss: 0.00131992	valid_1's binary_logloss: 0.158586
# [86]	training's binary_logloss: 0.00121938	valid_1's binary_logloss: 0.159819
# [87]	training's binary_logloss: 0.00113714	valid_1's binary_logloss: 0.161745
# [88]	training's binary_logloss: 0.00104357	valid_1's binary_logloss: 0.162829
# [89]	training's binary_logloss: 0.000980747	valid_1's binary_logloss: 0.159142
# [90]	training's binary_logloss: 0.00091528	valid_1's binary_logloss: 0.156765
# [91]	training's binary_logloss: 0.000866461	valid_1's binary_logloss: 0.158625
# [92]	training's binary_logloss: 0.000806128	valid_1's binary_logloss: 0.156832
# [93]	training's binary_logloss: 0.000752822	valid_1's binary_logloss: 0.154616
# [94]	training's binary_logloss: 0.000698378	valid_1's binary_logloss: 0.154263
# [95]	training's binary_logloss: 0.000657936	valid_1's binary_logloss: 0.157156
# [96]	training's binary_logloss: 0.000620701	valid_1's binary_logloss: 0.158617
# [97]	training's binary_logloss: 0.000587224	valid_1's binary_logloss: 0.157495
# [98]	training's binary_logloss: 0.000550018	valid_1's binary_logloss: 0.159413
# [99]	training's binary_logloss: 0.000509388	valid_1's binary_logloss: 0.15847
# [100]	training's binary_logloss: 0.000474125	valid_1's binary_logloss: 0.160746
# [101]	training's binary_logloss: 0.00044902	valid_1's binary_logloss: 0.16217
# [102]	training's binary_logloss: 0.000421913	valid_1's binary_logloss: 0.165293
# [103]	training's binary_logloss: 0.000396353	valid_1's binary_logloss: 0.164749
# [104]	training's binary_logloss: 0.000371597	valid_1's binary_logloss: 0.167097
# [105]	training's binary_logloss: 0.000347765	valid_1's binary_logloss: 0.167697
# [106]	training's binary_logloss: 0.000320932	valid_1's binary_logloss: 0.169462
# [107]	training's binary_logloss: 0.000301504	valid_1's binary_logloss: 0.169947
# [108]	training's binary_logloss: 0.000277892	valid_1's binary_logloss: 0.171
# [109]	training's binary_logloss: 0.0002621	valid_1's binary_logloss: 0.16907
# [110]	training's binary_logloss: 0.000245862	valid_1's binary_logloss: 0.169521
# [111]	training's binary_logloss: 0.000227541	valid_1's binary_logloss: 0.167719
# [112]	training's binary_logloss: 0.000215017	valid_1's binary_logloss: 0.166648
# [113]	training's binary_logloss: 0.000198413	valid_1's binary_logloss: 0.169053
# [114]	training's binary_logloss: 0.00018341	valid_1's binary_logloss: 0.169613
# [115]	training's binary_logloss: 0.000173123	valid_1's binary_logloss: 0.170059
# [116]	training's binary_logloss: 0.000161325	valid_1's binary_logloss: 0.1723
# [117]	training's binary_logloss: 0.000152748	valid_1's binary_logloss: 0.174733
# [118]	training's binary_logloss: 0.000142688	valid_1's binary_logloss: 0.173526
# [119]	training's binary_logloss: 0.000135073	valid_1's binary_logloss: 0.1751
# [120]	training's binary_logloss: 0.000128033	valid_1's binary_logloss: 0.178254
# [121]	training's binary_logloss: 0.000120523	valid_1's binary_logloss: 0.182968
# [122]	training's binary_logloss: 0.000113347	valid_1's binary_logloss: 0.179017
# [123]	training's binary_logloss: 0.000104539	valid_1's binary_logloss: 0.178326
# [124]	training's binary_logloss: 9.81886e-05	valid_1's binary_logloss: 0.177149
# [125]	training's binary_logloss: 9.06258e-05	valid_1's binary_logloss: 0.179171
# [126]	training's binary_logloss: 8.29418e-05	valid_1's binary_logloss: 0.180948
# [127]	training's binary_logloss: 7.78771e-05	valid_1's binary_logloss: 0.183861
# [128]	training's binary_logloss: 7.20705e-05	valid_1's binary_logloss: 0.187579
# [129]	training's binary_logloss: 6.67089e-05	valid_1's binary_logloss: 0.188122
# [130]	training's binary_logloss: 6.1535e-05	valid_1's binary_logloss: 0.1857
# [131]	training's binary_logloss: 5.71133e-05	valid_1's binary_logloss: 0.187442
# [132]	training's binary_logloss: 5.36521e-05	valid_1's binary_logloss: 0.188578
# [133]	training's binary_logloss: 5.03417e-05	valid_1's binary_logloss: 0.189729
# [134]	training's binary_logloss: 4.75967e-05	valid_1's binary_logloss: 0.187313
# [135]	training's binary_logloss: 4.4469e-05	valid_1's binary_logloss: 0.189279
# [136]	training's binary_logloss: 4.13393e-05	valid_1's binary_logloss: 0.191068
# [137]	training's binary_logloss: 3.89046e-05	valid_1's binary_logloss: 0.192414
# [138]	training's binary_logloss: 3.63978e-05	valid_1's binary_logloss: 0.191255
# [139]	training's binary_logloss: 3.39776e-05	valid_1's binary_logloss: 0.193453
# [140]	training's binary_logloss: 3.19529e-05	valid_1's binary_logloss: 0.196969
# [141]	training's binary_logloss: 2.97701e-05	valid_1's binary_logloss: 0.196378
# [142]	training's binary_logloss: 2.78301e-05	valid_1's binary_logloss: 0.196367
# [143]	training's binary_logloss: 2.64036e-05	valid_1's binary_logloss: 0.19869
# [144]	training's binary_logloss: 2.48198e-05	valid_1's binary_logloss: 0.200352
# [145]	training's binary_logloss: 2.34946e-05	valid_1's binary_logloss: 0.19712
# Early stopping, best iteration is:
# [45]	training's binary_logloss: 0.0196658	valid_1's binary_logloss: 0.122818
# LGBMClassifier(n_estimators=4000)

# %%
evals = [(X_test, y_test)]

# 학습
lgbm = LGBMClassifier(n_estimators = 400)
lgbm.fit(X_train, y_train, early_stopping_rounds = 50, eval_metric = 'logloss',
        eval_set = evals, verbose = True)
# Out:
# [1]	valid_0's binary_logloss: 0.565079
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's binary_logloss: 0.507451
# [3]	valid_0's binary_logloss: 0.458489
# [4]	valid_0's binary_logloss: 0.417481
# [5]	valid_0's binary_logloss: 0.385507
# [6]	valid_0's binary_logloss: 0.355773
# [7]	valid_0's binary_logloss: 0.329587
# [8]	valid_0's binary_logloss: 0.308478
# [9]	valid_0's binary_logloss: 0.285395
# [10]	valid_0's binary_logloss: 0.267055
# [11]	valid_0's binary_logloss: 0.252013
# [12]	valid_0's binary_logloss: 0.237018
# [13]	valid_0's binary_logloss: 0.224756
# [14]	valid_0's binary_logloss: 0.213383
# [15]	valid_0's binary_logloss: 0.203058
# [16]	valid_0's binary_logloss: 0.194015
# [17]	valid_0's binary_logloss: 0.186412
# [18]	valid_0's binary_logloss: 0.179108
# [19]	valid_0's binary_logloss: 0.174004
# [20]	valid_0's binary_logloss: 0.167155
# [21]	valid_0's binary_logloss: 0.162494
# [22]	valid_0's binary_logloss: 0.156886
# [23]	valid_0's binary_logloss: 0.152855
# [24]	valid_0's binary_logloss: 0.151113
# [25]	valid_0's binary_logloss: 0.148395
# [26]	valid_0's binary_logloss: 0.145869
# [27]	valid_0's binary_logloss: 0.143036
# [28]	valid_0's binary_logloss: 0.14033
# [29]	valid_0's binary_logloss: 0.139609
# [30]	valid_0's binary_logloss: 0.136109
# [31]	valid_0's binary_logloss: 0.134867
# [32]	valid_0's binary_logloss: 0.134729
# [33]	valid_0's binary_logloss: 0.1311
# [34]	valid_0's binary_logloss: 0.131143
# [35]	valid_0's binary_logloss: 0.129435
# [36]	valid_0's binary_logloss: 0.128474
# [37]	valid_0's binary_logloss: 0.126683
# [38]	valid_0's binary_logloss: 0.126112
# [39]	valid_0's binary_logloss: 0.122831
# [40]	valid_0's binary_logloss: 0.123162
# [41]	valid_0's binary_logloss: 0.125592
# [42]	valid_0's binary_logloss: 0.128293
# [43]	valid_0's binary_logloss: 0.128123
# [44]	valid_0's binary_logloss: 0.12789
# [45]	valid_0's binary_logloss: 0.122818
# [46]	valid_0's binary_logloss: 0.12496
# [47]	valid_0's binary_logloss: 0.125578
# [48]	valid_0's binary_logloss: 0.127381
# [49]	valid_0's binary_logloss: 0.128349
# [50]	valid_0's binary_logloss: 0.127004
# [51]	valid_0's binary_logloss: 0.130288
# [52]	valid_0's binary_logloss: 0.131362
# [53]	valid_0's binary_logloss: 0.133363
# [54]	valid_0's binary_logloss: 0.1332
# [55]	valid_0's binary_logloss: 0.134543
# [56]	valid_0's binary_logloss: 0.130803
# [57]	valid_0's binary_logloss: 0.130306
# [58]	valid_0's binary_logloss: 0.132514
# [59]	valid_0's binary_logloss: 0.133278
# [60]	valid_0's binary_logloss: 0.134804
# [61]	valid_0's binary_logloss: 0.136888
# [62]	valid_0's binary_logloss: 0.138745
# [63]	valid_0's binary_logloss: 0.140497
# [64]	valid_0's binary_logloss: 0.141368
# [65]	valid_0's binary_logloss: 0.140764
# [66]	valid_0's binary_logloss: 0.14348
# [67]	valid_0's binary_logloss: 0.143418
# [68]	valid_0's binary_logloss: 0.143682
# [69]	valid_0's binary_logloss: 0.145076
# [70]	valid_0's binary_logloss: 0.14686
# [71]	valid_0's binary_logloss: 0.148051
# [72]	valid_0's binary_logloss: 0.147664
# [73]	valid_0's binary_logloss: 0.149478
# [74]	valid_0's binary_logloss: 0.14708
# [75]	valid_0's binary_logloss: 0.14545
# [76]	valid_0's binary_logloss: 0.148767
# [77]	valid_0's binary_logloss: 0.149959
# [78]	valid_0's binary_logloss: 0.146083
# [79]	valid_0's binary_logloss: 0.14638
# [80]	valid_0's binary_logloss: 0.148461
# [81]	valid_0's binary_logloss: 0.15091
# [82]	valid_0's binary_logloss: 0.153011
# [83]	valid_0's binary_logloss: 0.154807
# [84]	valid_0's binary_logloss: 0.156501
# [85]	valid_0's binary_logloss: 0.158586
# [86]	valid_0's binary_logloss: 0.159819
# [87]	valid_0's binary_logloss: 0.161745
# [88]	valid_0's binary_logloss: 0.162829
# [89]	valid_0's binary_logloss: 0.159142
# [90]	valid_0's binary_logloss: 0.156765
# [91]	valid_0's binary_logloss: 0.158625
# [92]	valid_0's binary_logloss: 0.156832
# [93]	valid_0's binary_logloss: 0.154616
# [94]	valid_0's binary_logloss: 0.154263
# [95]	valid_0's binary_logloss: 0.157156
# Early stopping, best iteration is:
# [45]	valid_0's binary_logloss: 0.122818
# LGBMClassifier(n_estimators=400)

# %%
evals = [(X_test, y_test)]

# 학습
lgbm = LGBMClassifier(n_estimators = 4000)
lgbm.fit(X_train, y_train, early_stopping_rounds = 1000, eval_metric = 'logloss',
        eval_set = evals, verbose = True)
# Out:
# [1]	valid_0's binary_logloss: 0.565079
# Training until validation scores don't improve for 1000 rounds
# [2]	valid_0's binary_logloss: 0.507451
# [3]	valid_0's binary_logloss: 0.458489
# [4]	valid_0's binary_logloss: 0.417481
# [5]	valid_0's binary_logloss: 0.385507
# [6]	valid_0's binary_logloss: 0.355773
# [7]	valid_0's binary_logloss: 0.329587
# [8]	valid_0's binary_logloss: 0.308478
# [9]	valid_0's binary_logloss: 0.285395
# [10]	valid_0's binary_logloss: 0.267055
# [11]	valid_0's binary_logloss: 0.252013
# [12]	valid_0's binary_logloss: 0.237018
# [13]	valid_0's binary_logloss: 0.224756
# [14]	valid_0's binary_logloss: 0.213383
# [15]	valid_0's binary_logloss: 0.203058
# [16]	valid_0's binary_logloss: 0.194015
# [17]	valid_0's binary_logloss: 0.186412
# [18]	valid_0's binary_logloss: 0.179108
# [19]	valid_0's binary_logloss: 0.174004
# [20]	valid_0's binary_logloss: 0.167155
# [21]	valid_0's binary_logloss: 0.162494
# [22]	valid_0's binary_logloss: 0.156886
# [23]	valid_0's binary_logloss: 0.152855
# [24]	valid_0's binary_logloss: 0.151113
# [25]	valid_0's binary_logloss: 0.148395
# [26]	valid_0's binary_logloss: 0.145869
# [27]	valid_0's binary_logloss: 0.143036
# [28]	valid_0's binary_logloss: 0.14033
# [29]	valid_0's binary_logloss: 0.139609
# [30]	valid_0's binary_logloss: 0.136109
# [31]	valid_0's binary_logloss: 0.134867
# [32]	valid_0's binary_logloss: 0.134729
# [33]	valid_0's binary_logloss: 0.1311
# [34]	valid_0's binary_logloss: 0.131143
# [35]	valid_0's binary_logloss: 0.129435
# [36]	valid_0's binary_logloss: 0.128474
# [37]	valid_0's binary_logloss: 0.126683
# [38]	valid_0's binary_logloss: 0.126112
# [39]	valid_0's binary_logloss: 0.122831
# [40]	valid_0's binary_logloss: 0.123162
# [41]	valid_0's binary_logloss: 0.125592
# [42]	valid_0's binary_logloss: 0.128293
# [43]	valid_0's binary_logloss: 0.128123
# [44]	valid_0's binary_logloss: 0.12789
# [45]	valid_0's binary_logloss: 0.122818
# [46]	valid_0's binary_logloss: 0.12496
# [47]	valid_0's binary_logloss: 0.125578
# [48]	valid_0's binary_logloss: 0.127381
# [49]	valid_0's binary_logloss: 0.128349
# [50]	valid_0's binary_logloss: 0.127004
# [51]	valid_0's binary_logloss: 0.130288
# [52]	valid_0's binary_logloss: 0.131362
# [53]	valid_0's binary_logloss: 0.133363
# [54]	valid_0's binary_logloss: 0.1332
# [55]	valid_0's binary_logloss: 0.134543
# [56]	valid_0's binary_logloss: 0.130803
# [57]	valid_0's binary_logloss: 0.130306
# [58]	valid_0's binary_logloss: 0.132514
# [59]	valid_0's binary_logloss: 0.133278
# [60]	valid_0's binary_logloss: 0.134804
# [61]	valid_0's binary_logloss: 0.136888
# [62]	valid_0's binary_logloss: 0.138745
# [63]	valid_0's binary_logloss: 0.140497
# [64]	valid_0's binary_logloss: 0.141368
# [65]	valid_0's binary_logloss: 0.140764
# [66]	valid_0's binary_logloss: 0.14348
# [67]	valid_0's binary_logloss: 0.143418
# [68]	valid_0's binary_logloss: 0.143682
# [69]	valid_0's binary_logloss: 0.145076
# [70]	valid_0's binary_logloss: 0.14686
# [71]	valid_0's binary_logloss: 0.148051
# [72]	valid_0's binary_logloss: 0.147664
# [73]	valid_0's binary_logloss: 0.149478
# [74]	valid_0's binary_logloss: 0.14708
# [75]	valid_0's binary_logloss: 0.14545
# [76]	valid_0's binary_logloss: 0.148767
# [77]	valid_0's binary_logloss: 0.149959
# [78]	valid_0's binary_logloss: 0.146083
# [79]	valid_0's binary_logloss: 0.14638
# [80]	valid_0's binary_logloss: 0.148461
# [81]	valid_0's binary_logloss: 0.15091
# [82]	valid_0's binary_logloss: 0.153011
# [83]	valid_0's binary_logloss: 0.154807
# [84]	valid_0's binary_logloss: 0.156501
# [85]	valid_0's binary_logloss: 0.158586
# [86]	valid_0's binary_logloss: 0.159819
# [87]	valid_0's binary_logloss: 0.161745
# [88]	valid_0's binary_logloss: 0.162829
# [89]	valid_0's binary_logloss: 0.159142
# [90]	valid_0's binary_logloss: 0.156765
# [91]	valid_0's binary_logloss: 0.158625
# [92]	valid_0's binary_logloss: 0.156832
# [93]	valid_0's binary_logloss: 0.154616
# [94]	valid_0's binary_logloss: 0.154263
# [95]	valid_0's binary_logloss: 0.157156
# [96]	valid_0's binary_logloss: 0.158617
# [97]	valid_0's binary_logloss: 0.157495
# [98]	valid_0's binary_logloss: 0.159413
# [99]	valid_0's binary_logloss: 0.15847
# [100]	valid_0's binary_logloss: 0.160746
# [101]	valid_0's binary_logloss: 0.16217
# [102]	valid_0's binary_logloss: 0.165293
# [103]	valid_0's binary_logloss: 0.164749
# [104]	valid_0's binary_logloss: 0.167097
# [105]	valid_0's binary_logloss: 0.167697
# [106]	valid_0's binary_logloss: 0.169462
# [107]	valid_0's binary_logloss: 0.169947
# [108]	valid_0's binary_logloss: 0.171
# [109]	valid_0's binary_logloss: 0.16907
# [110]	valid_0's binary_logloss: 0.169521
# [111]	valid_0's binary_logloss: 0.167719
# [112]	valid_0's binary_logloss: 0.166648
# [113]	valid_0's binary_logloss: 0.169053
# [114]	valid_0's binary_logloss: 0.169613
# [115]	valid_0's binary_logloss: 0.170059
# [116]	valid_0's binary_logloss: 0.1723
# [117]	valid_0's binary_logloss: 0.174733
# [118]	valid_0's binary_logloss: 0.173526
# [119]	valid_0's binary_logloss: 0.1751
# [120]	valid_0's binary_logloss: 0.178254
# [121]	valid_0's binary_logloss: 0.182968
# [122]	valid_0's binary_logloss: 0.179017
# [123]	valid_0's binary_logloss: 0.178326
# [124]	valid_0's binary_logloss: 0.177149
# [125]	valid_0's binary_logloss: 0.179171
# [126]	valid_0's binary_logloss: 0.180948
# [127]	valid_0's binary_logloss: 0.183861
# [128]	valid_0's binary_logloss: 0.187579
# [129]	valid_0's binary_logloss: 0.188122
# [130]	valid_0's binary_logloss: 0.1857
# [131]	valid_0's binary_logloss: 0.187442
# [132]	valid_0's binary_logloss: 0.188578
# [133]	valid_0's binary_logloss: 0.189729
# [134]	valid_0's binary_logloss: 0.187313
# [135]	valid_0's binary_logloss: 0.189279
# [136]	valid_0's binary_logloss: 0.191068
# [137]	valid_0's binary_logloss: 0.192414
# [138]	valid_0's binary_logloss: 0.191255
# [139]	valid_0's binary_logloss: 0.193453
# [140]	valid_0's binary_logloss: 0.196969
# [141]	valid_0's binary_logloss: 0.196378
# [142]	valid_0's binary_logloss: 0.196367
# [143]	valid_0's binary_logloss: 0.19869
# [144]	valid_0's binary_logloss: 0.200352
# [145]	valid_0's binary_logloss: 0.19712
# [146]	valid_0's binary_logloss: 0.200546
# [147]	valid_0's binary_logloss: 0.203184
# [148]	valid_0's binary_logloss: 0.200576
# [149]	valid_0's binary_logloss: 0.200915
# [150]	valid_0's binary_logloss: 0.19998
# [151]	valid_0's binary_logloss: 0.198883
# [152]	valid_0's binary_logloss: 0.196523
# [153]	valid_0's binary_logloss: 0.197909
# [154]	valid_0's binary_logloss: 0.199803
# [155]	valid_0's binary_logloss: 0.198481
# [156]	valid_0's binary_logloss: 0.196407
# [157]	valid_0's binary_logloss: 0.199684
# [158]	valid_0's binary_logloss: 0.198176
# [159]	valid_0's binary_logloss: 0.199294
# [160]	valid_0's binary_logloss: 0.202686
# [161]	valid_0's binary_logloss: 0.203961
# [162]	valid_0's binary_logloss: 0.20328
# [163]	valid_0's binary_logloss: 0.205113
# [164]	valid_0's binary_logloss: 0.204102
# [165]	valid_0's binary_logloss: 0.203717
# [166]	valid_0's binary_logloss: 0.204788
# [167]	valid_0's binary_logloss: 0.204594
# [168]	valid_0's binary_logloss: 0.205364
# [169]	valid_0's binary_logloss: 0.20555
# [170]	valid_0's binary_logloss: 0.206488
# [171]	valid_0's binary_logloss: 0.206142
# [172]	valid_0's binary_logloss: 0.207206
# [173]	valid_0's binary_logloss: 0.209161
# [174]	valid_0's binary_logloss: 0.209071
# [175]	valid_0's binary_logloss: 0.208487
# [176]	valid_0's binary_logloss: 0.209141
# [177]	valid_0's binary_logloss: 0.209784
# [178]	valid_0's binary_logloss: 0.211655
# [179]	valid_0's binary_logloss: 0.210285
# [180]	valid_0's binary_logloss: 0.210128
# [181]	valid_0's binary_logloss: 0.210559
# [182]	valid_0's binary_logloss: 0.210441
# [183]	valid_0's binary_logloss: 0.210947
# [184]	valid_0's binary_logloss: 0.211116
# [185]	valid_0's binary_logloss: 0.213217
# [186]	valid_0's binary_logloss: 0.212991
# [187]	valid_0's binary_logloss: 0.213536
# [188]	valid_0's binary_logloss: 0.212228
# [189]	valid_0's binary_logloss: 0.212157
# [190]	valid_0's binary_logloss: 0.212004
# [191]	valid_0's binary_logloss: 0.212155
# [192]	valid_0's binary_logloss: 0.214012
# [193]	valid_0's binary_logloss: 0.214556
# [194]	valid_0's binary_logloss: 0.215286
# [195]	valid_0's binary_logloss: 0.215938
# [196]	valid_0's binary_logloss: 0.215236
# [197]	valid_0's binary_logloss: 0.21507
# [198]	valid_0's binary_logloss: 0.214658
# [199]	valid_0's binary_logloss: 0.215958
# [200]	valid_0's binary_logloss: 0.215746
# [201]	valid_0's binary_logloss: 0.215604
# [202]	valid_0's binary_logloss: 0.215604
# [203]	valid_0's binary_logloss: 0.215407
# [204]	valid_0's binary_logloss: 0.213218
# [205]	valid_0's binary_logloss: 0.213086
# [206]	valid_0's binary_logloss: 0.213153
# [207]	valid_0's binary_logloss: 0.213834
# [208]	valid_0's binary_logloss: 0.214034
# [209]	valid_0's binary_logloss: 0.213891
# [210]	valid_0's binary_logloss: 0.213133
# [211]	valid_0's binary_logloss: 0.21291
# [212]	valid_0's binary_logloss: 0.213275
# [213]	valid_0's binary_logloss: 0.212523
# [214]	valid_0's binary_logloss: 0.212404
# [215]	valid_0's binary_logloss: 0.212518
# [216]	valid_0's binary_logloss: 0.212868
# [217]	valid_0's binary_logloss: 0.212127
# [218]	valid_0's binary_logloss: 0.211481
# [219]	valid_0's binary_logloss: 0.211302
# [220]	valid_0's binary_logloss: 0.211658
# [221]	valid_0's binary_logloss: 0.21166
# [222]	valid_0's binary_logloss: 0.212113
# [223]	valid_0's binary_logloss: 0.21198
# [224]	valid_0's binary_logloss: 0.211864
# [225]	valid_0's binary_logloss: 0.211972
# [226]	valid_0's binary_logloss: 0.211335
# [227]	valid_0's binary_logloss: 0.211163
# [228]	valid_0's binary_logloss: 0.21084
# [229]	valid_0's binary_logloss: 0.210716
# [230]	valid_0's binary_logloss: 0.21072
# [231]	valid_0's binary_logloss: 0.210557
# [232]	valid_0's binary_logloss: 0.210645
# [233]	valid_0's binary_logloss: 0.210046
# [234]	valid_0's binary_logloss: 0.209931
# [235]	valid_0's binary_logloss: 0.209741
# [236]	valid_0's binary_logloss: 0.210157
# [237]	valid_0's binary_logloss: 0.209977
# [238]	valid_0's binary_logloss: 0.209979
# [239]	valid_0's binary_logloss: 0.209827
# [240]	valid_0's binary_logloss: 0.20991
# [241]	valid_0's binary_logloss: 0.210365
# [242]	valid_0's binary_logloss: 0.210191
# [243]	valid_0's binary_logloss: 0.210102
# [244]	valid_0's binary_logloss: 0.210744
# [245]	valid_0's binary_logloss: 0.21119
# [246]	valid_0's binary_logloss: 0.211101
# [247]	valid_0's binary_logloss: 0.211192
# [248]	valid_0's binary_logloss: 0.211026
# [249]	valid_0's binary_logloss: 0.210521
# [250]	valid_0's binary_logloss: 0.210387
# [251]	valid_0's binary_logloss: 0.210284
# [252]	valid_0's binary_logloss: 0.209798
# [253]	valid_0's binary_logloss: 0.209695
# [254]	valid_0's binary_logloss: 0.209621
# [255]	valid_0's binary_logloss: 0.210046
# [256]	valid_0's binary_logloss: 0.209926
# [257]	valid_0's binary_logloss: 0.209626
# [258]	valid_0's binary_logloss: 0.209525
# [259]	valid_0's binary_logloss: 0.2096
# [260]	valid_0's binary_logloss: 0.209525
# [261]	valid_0's binary_logloss: 0.209927
# [262]	valid_0's binary_logloss: 0.209813
# [263]	valid_0's binary_logloss: 0.209646
# [264]	valid_0's binary_logloss: 0.209694
# [265]	valid_0's binary_logloss: 0.209573
# [266]	valid_0's binary_logloss: 0.209048
# [267]	valid_0's binary_logloss: 0.208951
# [268]	valid_0's binary_logloss: 0.209339
# [269]	valid_0's binary_logloss: 0.209386
# [270]	valid_0's binary_logloss: 0.209226
# [271]	valid_0's binary_logloss: 0.209107
# [272]	valid_0's binary_logloss: 0.209
# [273]	valid_0's binary_logloss: 0.208934
# [274]	valid_0's binary_logloss: 0.209004
# [275]	valid_0's binary_logloss: 0.208842
# [276]	valid_0's binary_logloss: 0.208751
# [277]	valid_0's binary_logloss: 0.209136
# [278]	valid_0's binary_logloss: 0.208961
# [279]	valid_0's binary_logloss: 0.208847
# [280]	valid_0's binary_logloss: 0.208754
# [281]	valid_0's binary_logloss: 0.208666
# [282]	valid_0's binary_logloss: 0.208486
# [283]	valid_0's binary_logloss: 0.208386
# [284]	valid_0's binary_logloss: 0.207962
# [285]	valid_0's binary_logloss: 0.207878
# [286]	valid_0's binary_logloss: 0.208248
# [287]	valid_0's binary_logloss: 0.20814
# [288]	valid_0's binary_logloss: 0.207969
# [289]	valid_0's binary_logloss: 0.207874
# [290]	valid_0's binary_logloss: 0.207792
# [291]	valid_0's binary_logloss: 0.207623
# [292]	valid_0's binary_logloss: 0.20752
# [293]	valid_0's binary_logloss: 0.207389
# [294]	valid_0's binary_logloss: 0.207308
# [295]	valid_0's binary_logloss: 0.207214
# [296]	valid_0's binary_logloss: 0.207052
# [297]	valid_0's binary_logloss: 0.207408
# [298]	valid_0's binary_logloss: 0.20731
# [299]	valid_0's binary_logloss: 0.207209
# [300]	valid_0's binary_logloss: 0.207039
# [301]	valid_0's binary_logloss: 0.206959
# [302]	valid_0's binary_logloss: 0.206868
# [303]	valid_0's binary_logloss: 0.206738
# [304]	valid_0's binary_logloss: 0.206641
# [305]	valid_0's binary_logloss: 0.206567
# [306]	valid_0's binary_logloss: 0.206408
# [307]	valid_0's binary_logloss: 0.206758
# [308]	valid_0's binary_logloss: 0.206668
# [309]	valid_0's binary_logloss: 0.20652
# [310]	valid_0's binary_logloss: 0.206425
# [311]	valid_0's binary_logloss: 0.206352
# [312]	valid_0's binary_logloss: 0.206689
# [313]	valid_0's binary_logloss: 0.206543
# [314]	valid_0's binary_logloss: 0.20665
# [315]	valid_0's binary_logloss: 0.206532
# [316]	valid_0's binary_logloss: 0.206458
# [317]	valid_0's binary_logloss: 0.206364
# [318]	valid_0's binary_logloss: 0.206225
# [319]	valid_0's binary_logloss: 0.206127
# [320]	valid_0's binary_logloss: 0.206058
# [321]	valid_0's binary_logloss: 0.205919
# [322]	valid_0's binary_logloss: 0.20583
# [323]	valid_0's binary_logloss: 0.206159
# [324]	valid_0's binary_logloss: 0.206072
# [325]	valid_0's binary_logloss: 0.205939
# [326]	valid_0's binary_logloss: 0.20587
# [327]	valid_0's binary_logloss: 0.206184
# [328]	valid_0's binary_logloss: 0.206099
# [329]	valid_0's binary_logloss: 0.205967
# [330]	valid_0's binary_logloss: 0.206066
# [331]	valid_0's binary_logloss: 0.206
# [332]	valid_0's binary_logloss: 0.205869
# [333]	valid_0's binary_logloss: 0.205788
# [334]	valid_0's binary_logloss: 0.206094
# [335]	valid_0's binary_logloss: 0.206009
# [336]	valid_0's binary_logloss: 0.20556
# [337]	valid_0's binary_logloss: 0.205651
# [338]	valid_0's binary_logloss: 0.205527
# [339]	valid_0's binary_logloss: 0.205459
# [340]	valid_0's binary_logloss: 0.205032
# [341]	valid_0's binary_logloss: 0.20497
# [342]	valid_0's binary_logloss: 0.204863
# [343]	valid_0's binary_logloss: 0.204442
# [344]	valid_0's binary_logloss: 0.204146
# [345]	valid_0's binary_logloss: 0.204432
# [346]	valid_0's binary_logloss: 0.204358
# [347]	valid_0's binary_logloss: 0.203946
# [348]	valid_0's binary_logloss: 0.20403
# [349]	valid_0's binary_logloss: 0.203976
# [350]	valid_0's binary_logloss: 0.203567
# [351]	valid_0's binary_logloss: 0.203461
# [352]	valid_0's binary_logloss: 0.203408
# [353]	valid_0's binary_logloss: 0.203676
# [354]	valid_0's binary_logloss: 0.203756
# [355]	valid_0's binary_logloss: 0.20365
# [356]	valid_0's binary_logloss: 0.203374
# [357]	valid_0's binary_logloss: 0.202775
# [358]	valid_0's binary_logloss: 0.202676
# [359]	valid_0's binary_logloss: 0.202626
# [360]	valid_0's binary_logloss: 0.202234
# [361]	valid_0's binary_logloss: 0.202169
# [362]	valid_0's binary_logloss: 0.202067
# [363]	valid_0's binary_logloss: 0.202324
# [364]	valid_0's binary_logloss: 0.202276
# [365]	valid_0's binary_logloss: 0.201904
# [366]	valid_0's binary_logloss: 0.20181
# [367]	valid_0's binary_logloss: 0.201749
# [368]	valid_0's binary_logloss: 0.201658
# [369]	valid_0's binary_logloss: 0.201304
# [370]	valid_0's binary_logloss: 0.201066
# [371]	valid_0's binary_logloss: 0.201307
# [372]	valid_0's binary_logloss: 0.201221
# [373]	valid_0's binary_logloss: 0.200878
# [374]	valid_0's binary_logloss: 0.200643
# [375]	valid_0's binary_logloss: 0.200862
# [376]	valid_0's binary_logloss: 0.200806
# [377]	valid_0's binary_logloss: 0.20047
# [378]	valid_0's binary_logloss: 0.20039
# [379]	valid_0's binary_logloss: 0.200079
# [380]	valid_0's binary_logloss: 0.199917
# [381]	valid_0's binary_logloss: 0.200118
# [382]	valid_0's binary_logloss: 0.200076
# [383]	valid_0's binary_logloss: 0.2
# [384]	valid_0's binary_logloss: 0.199926
# [385]	valid_0's binary_logloss: 0.20012
# [386]	valid_0's binary_logloss: 0.200079
# [387]	valid_0's binary_logloss: 0.199747
# [388]	valid_0's binary_logloss: 0.199594
# [389]	valid_0's binary_logloss: 0.199521
# [390]	valid_0's binary_logloss: 0.199701
# [391]	valid_0's binary_logloss: 0.199662
# [392]	valid_0's binary_logloss: 0.199349
# [393]	valid_0's binary_logloss: 0.199284
# [394]	valid_0's binary_logloss: 0.199001
# [395]	valid_0's binary_logloss: 0.198943
# [396]	valid_0's binary_logloss: 0.198687
# [397]	valid_0's binary_logloss: 0.198635
# [398]	valid_0's binary_logloss: 0.198594
# [399]	valid_0's binary_logloss: 0.198429
# [400]	valid_0's binary_logloss: 0.198244
# [401]	valid_0's binary_logloss: 0.198244
# [402]	valid_0's binary_logloss: 0.198244
# [403]	valid_0's binary_logloss: 0.198244
# [404]	valid_0's binary_logloss: 0.198244
# [405]	valid_0's binary_logloss: 0.198244
# [406]	valid_0's binary_logloss: 0.198244
# [407]	valid_0's binary_logloss: 0.198244
# [408]	valid_0's binary_logloss: 0.198244
# [409]	valid_0's binary_logloss: 0.198244
# [410]	valid_0's binary_logloss: 0.198244
# [411]	valid_0's binary_logloss: 0.198244
# [412]	valid_0's binary_logloss: 0.198244
# [413]	valid_0's binary_logloss: 0.198244
# [414]	valid_0's binary_logloss: 0.198244
# [415]	valid_0's binary_logloss: 0.198244
# [416]	valid_0's binary_logloss: 0.198244
# [417]	valid_0's binary_logloss: 0.198244
# [418]	valid_0's binary_logloss: 0.198244
# [419]	valid_0's binary_logloss: 0.198244
# [420]	valid_0's binary_logloss: 0.198244
# [421]	valid_0's binary_logloss: 0.198244
# [422]	valid_0's binary_logloss: 0.198244
# [423]	valid_0's binary_logloss: 0.198244
# [424]	valid_0's binary_logloss: 0.198244
# [425]	valid_0's binary_logloss: 0.198244
# [426]	valid_0's binary_logloss: 0.198244
# [427]	valid_0's binary_logloss: 0.198244
# [428]	valid_0's binary_logloss: 0.198244
# [429]	valid_0's binary_logloss: 0.198244
# [430]	valid_0's binary_logloss: 0.198244
# [431]	valid_0's binary_logloss: 0.198244
# [432]	valid_0's binary_logloss: 0.198244
# [433]	valid_0's binary_logloss: 0.198244
# [434]	valid_0's binary_logloss: 0.198244
# [435]	valid_0's binary_logloss: 0.198244
# [436]	valid_0's binary_logloss: 0.198244
# [437]	valid_0's binary_logloss: 0.198244
# [438]	valid_0's binary_logloss: 0.198244
# [439]	valid_0's binary_logloss: 0.198244
# [440]	valid_0's binary_logloss: 0.198244
# [441]	valid_0's binary_logloss: 0.198244
# [442]	valid_0's binary_logloss: 0.198244
# [443]	valid_0's binary_logloss: 0.198244
# [444]	valid_0's binary_logloss: 0.198244
# [445]	valid_0's binary_logloss: 0.198244
# [446]	valid_0's binary_logloss: 0.198244
# [447]	valid_0's binary_logloss: 0.198244
# [448]	valid_0's binary_logloss: 0.198244
# [449]	valid_0's binary_logloss: 0.198244
# [450]	valid_0's binary_logloss: 0.198244
# [451]	valid_0's binary_logloss: 0.198244
# [452]	valid_0's binary_logloss: 0.198244
# [453]	valid_0's binary_logloss: 0.198244
# [454]	valid_0's binary_logloss: 0.198244
# [455]	valid_0's binary_logloss: 0.198244
# [456]	valid_0's binary_logloss: 0.198244
# [457]	valid_0's binary_logloss: 0.198244
# [458]	valid_0's binary_logloss: 0.198244
# [459]	valid_0's binary_logloss: 0.198244
# [460]	valid_0's binary_logloss: 0.198244
# [461]	valid_0's binary_logloss: 0.198244
# [462]	valid_0's binary_logloss: 0.198244
# [463]	valid_0's binary_logloss: 0.198244
# [464]	valid_0's binary_logloss: 0.198244
# [465]	valid_0's binary_logloss: 0.198244
# [466]	valid_0's binary_logloss: 0.198244
# [467]	valid_0's binary_logloss: 0.198244
# [468]	valid_0's binary_logloss: 0.198244
# [469]	valid_0's binary_logloss: 0.198244
# [470]	valid_0's binary_logloss: 0.198244
# [471]	valid_0's binary_logloss: 0.198244
# [472]	valid_0's binary_logloss: 0.198244
# [473]	valid_0's binary_logloss: 0.198244
# [474]	valid_0's binary_logloss: 0.198244
# [475]	valid_0's binary_logloss: 0.198244
# [476]	valid_0's binary_logloss: 0.198244
# [477]	valid_0's binary_logloss: 0.198244
# [478]	valid_0's binary_logloss: 0.198244
# [479]	valid_0's binary_logloss: 0.198244
# [480]	valid_0's binary_logloss: 0.198244
# [481]	valid_0's binary_logloss: 0.198244
# [482]	valid_0's binary_logloss: 0.198244
# [483]	valid_0's binary_logloss: 0.198244
# [484]	valid_0's binary_logloss: 0.198244
# [485]	valid_0's binary_logloss: 0.198244
# [486]	valid_0's binary_logloss: 0.198244
# [487]	valid_0's binary_logloss: 0.198244
# [488]	valid_0's binary_logloss: 0.198244
# [489]	valid_0's binary_logloss: 0.198244
# [490]	valid_0's binary_logloss: 0.198244
# [491]	valid_0's binary_logloss: 0.198244
# [492]	valid_0's binary_logloss: 0.198244
# [493]	valid_0's binary_logloss: 0.198244
# [494]	valid_0's binary_logloss: 0.198244
# [495]	valid_0's binary_logloss: 0.198244
# [496]	valid_0's binary_logloss: 0.198244
# [497]	valid_0's binary_logloss: 0.198244
# [498]	valid_0's binary_logloss: 0.198244
# [499]	valid_0's binary_logloss: 0.198244
# [500]	valid_0's binary_logloss: 0.198244
# [501]	valid_0's binary_logloss: 0.198244
# [502]	valid_0's binary_logloss: 0.198244
# [503]	valid_0's binary_logloss: 0.198244
# [504]	valid_0's binary_logloss: 0.198244
# [505]	valid_0's binary_logloss: 0.198244
# [506]	valid_0's binary_logloss: 0.198244
# [507]	valid_0's binary_logloss: 0.198244
# [508]	valid_0's binary_logloss: 0.198244
# [509]	valid_0's binary_logloss: 0.198244
# [510]	valid_0's binary_logloss: 0.198244
# [511]	valid_0's binary_logloss: 0.198244
# [512]	valid_0's binary_logloss: 0.198244
# [513]	valid_0's binary_logloss: 0.198244
# [514]	valid_0's binary_logloss: 0.198244
# [515]	valid_0's binary_logloss: 0.198244
# [516]	valid_0's binary_logloss: 0.198244
# [517]	valid_0's binary_logloss: 0.198244
# [518]	valid_0's binary_logloss: 0.198244
# [519]	valid_0's binary_logloss: 0.198244
# [520]	valid_0's binary_logloss: 0.198244
# [521]	valid_0's binary_logloss: 0.198244
# [522]	valid_0's binary_logloss: 0.198244
# [523]	valid_0's binary_logloss: 0.198244
# [524]	valid_0's binary_logloss: 0.198244
# [525]	valid_0's binary_logloss: 0.198244
# [526]	valid_0's binary_logloss: 0.198244
# [527]	valid_0's binary_logloss: 0.198244
# [528]	valid_0's binary_logloss: 0.198244
# [529]	valid_0's binary_logloss: 0.198244
# [530]	valid_0's binary_logloss: 0.198244
# [531]	valid_0's binary_logloss: 0.198244
# [532]	valid_0's binary_logloss: 0.198244
# [533]	valid_0's binary_logloss: 0.198244
# [534]	valid_0's binary_logloss: 0.198244
# [535]	valid_0's binary_logloss: 0.198244
# [536]	valid_0's binary_logloss: 0.198244
# [537]	valid_0's binary_logloss: 0.198244
# [538]	valid_0's binary_logloss: 0.198244
# [539]	valid_0's binary_logloss: 0.198244
# [540]	valid_0's binary_logloss: 0.198244
# [541]	valid_0's binary_logloss: 0.198244
# [542]	valid_0's binary_logloss: 0.198244
# [543]	valid_0's binary_logloss: 0.198244
# [544]	valid_0's binary_logloss: 0.198244
# [545]	valid_0's binary_logloss: 0.198244
# [546]	valid_0's binary_logloss: 0.198244
# [547]	valid_0's binary_logloss: 0.198244
# [548]	valid_0's binary_logloss: 0.198244
# [549]	valid_0's binary_logloss: 0.198244
# [550]	valid_0's binary_logloss: 0.198244
# [551]	valid_0's binary_logloss: 0.198244
# [552]	valid_0's binary_logloss: 0.198244
# [553]	valid_0's binary_logloss: 0.198244
# [554]	valid_0's binary_logloss: 0.198244
# [555]	valid_0's binary_logloss: 0.198244
# [556]	valid_0's binary_logloss: 0.198244
# [557]	valid_0's binary_logloss: 0.198244
# [558]	valid_0's binary_logloss: 0.198244
# [559]	valid_0's binary_logloss: 0.198244
# [560]	valid_0's binary_logloss: 0.198244
# [561]	valid_0's binary_logloss: 0.198244
# [562]	valid_0's binary_logloss: 0.198244
# [563]	valid_0's binary_logloss: 0.198244
# [564]	valid_0's binary_logloss: 0.198244
# [565]	valid_0's binary_logloss: 0.198244
# [566]	valid_0's binary_logloss: 0.198244
# [567]	valid_0's binary_logloss: 0.198244
# [568]	valid_0's binary_logloss: 0.198244
# [569]	valid_0's binary_logloss: 0.198244
# [570]	valid_0's binary_logloss: 0.198244
# [571]	valid_0's binary_logloss: 0.198244
# [572]	valid_0's binary_logloss: 0.198244
# [573]	valid_0's binary_logloss: 0.198244
# [574]	valid_0's binary_logloss: 0.198244
# [575]	valid_0's binary_logloss: 0.198244
# [576]	valid_0's binary_logloss: 0.198244
# [577]	valid_0's binary_logloss: 0.198244
# [578]	valid_0's binary_logloss: 0.198244
# [579]	valid_0's binary_logloss: 0.198244
# [580]	valid_0's binary_logloss: 0.198244
# [581]	valid_0's binary_logloss: 0.198244
# [582]	valid_0's binary_logloss: 0.198244
# [583]	valid_0's binary_logloss: 0.198244
# [584]	valid_0's binary_logloss: 0.198244
# [585]	valid_0's binary_logloss: 0.198244
# [586]	valid_0's binary_logloss: 0.198244
# [587]	valid_0's binary_logloss: 0.198244
# [588]	valid_0's binary_logloss: 0.198244
# [589]	valid_0's binary_logloss: 0.198244
# [590]	valid_0's binary_logloss: 0.198244
# [591]	valid_0's binary_logloss: 0.198244
# [592]	valid_0's binary_logloss: 0.198244
# [593]	valid_0's binary_logloss: 0.198244
# [594]	valid_0's binary_logloss: 0.198244
# [595]	valid_0's binary_logloss: 0.198244
# [596]	valid_0's binary_logloss: 0.198244
# [597]	valid_0's binary_logloss: 0.198244
# [598]	valid_0's binary_logloss: 0.198244
# [599]	valid_0's binary_logloss: 0.198244
# [600]	valid_0's binary_logloss: 0.198244
# [601]	valid_0's binary_logloss: 0.198244
# [602]	valid_0's binary_logloss: 0.198244
# [603]	valid_0's binary_logloss: 0.198244
# [604]	valid_0's binary_logloss: 0.198244
# [605]	valid_0's binary_logloss: 0.198244
# [606]	valid_0's binary_logloss: 0.198244
# [607]	valid_0's binary_logloss: 0.198244
# [608]	valid_0's binary_logloss: 0.198244
# [609]	valid_0's binary_logloss: 0.198244
# [610]	valid_0's binary_logloss: 0.198244
# [611]	valid_0's binary_logloss: 0.198244
# [612]	valid_0's binary_logloss: 0.198244
# [613]	valid_0's binary_logloss: 0.198244
# [614]	valid_0's binary_logloss: 0.198244
# [615]	valid_0's binary_logloss: 0.198244
# [616]	valid_0's binary_logloss: 0.198244
# [617]	valid_0's binary_logloss: 0.198244
# [618]	valid_0's binary_logloss: 0.198244
# [619]	valid_0's binary_logloss: 0.198244
# [620]	valid_0's binary_logloss: 0.198244
# [621]	valid_0's binary_logloss: 0.198244
# [622]	valid_0's binary_logloss: 0.198244
# [623]	valid_0's binary_logloss: 0.198244
# [624]	valid_0's binary_logloss: 0.198244
# [625]	valid_0's binary_logloss: 0.198244
# [626]	valid_0's binary_logloss: 0.198244
# [627]	valid_0's binary_logloss: 0.198244
# [628]	valid_0's binary_logloss: 0.198244
# [629]	valid_0's binary_logloss: 0.198244
# [630]	valid_0's binary_logloss: 0.198244
# [631]	valid_0's binary_logloss: 0.198244
# [632]	valid_0's binary_logloss: 0.198244
# [633]	valid_0's binary_logloss: 0.198244
# [634]	valid_0's binary_logloss: 0.198244
# [635]	valid_0's binary_logloss: 0.198244
# [636]	valid_0's binary_logloss: 0.198244
# [637]	valid_0's binary_logloss: 0.198244
# [638]	valid_0's binary_logloss: 0.198244
# [639]	valid_0's binary_logloss: 0.198244
# [640]	valid_0's binary_logloss: 0.198244
# [641]	valid_0's binary_logloss: 0.198244
# [642]	valid_0's binary_logloss: 0.198244
# [643]	valid_0's binary_logloss: 0.198244
# [644]	valid_0's binary_logloss: 0.198244
# [645]	valid_0's binary_logloss: 0.198244
# [646]	valid_0's binary_logloss: 0.198244
# [647]	valid_0's binary_logloss: 0.198244
# [648]	valid_0's binary_logloss: 0.198244
# [649]	valid_0's binary_logloss: 0.198244
# [650]	valid_0's binary_logloss: 0.198244
# [651]	valid_0's binary_logloss: 0.198244
# [652]	valid_0's binary_logloss: 0.198244
# [653]	valid_0's binary_logloss: 0.198244
# [654]	valid_0's binary_logloss: 0.198244
# [655]	valid_0's binary_logloss: 0.198244
# [656]	valid_0's binary_logloss: 0.198244
# [657]	valid_0's binary_logloss: 0.198244
# [658]	valid_0's binary_logloss: 0.198244
# [659]	valid_0's binary_logloss: 0.198244
# [660]	valid_0's binary_logloss: 0.198244
# [661]	valid_0's binary_logloss: 0.198244
# [662]	valid_0's binary_logloss: 0.198244
# [663]	valid_0's binary_logloss: 0.198244
# [664]	valid_0's binary_logloss: 0.198244
# [665]	valid_0's binary_logloss: 0.198244
# [666]	valid_0's binary_logloss: 0.198244
# [667]	valid_0's binary_logloss: 0.198244
# [668]	valid_0's binary_logloss: 0.198244
# [669]	valid_0's binary_logloss: 0.198244
# [670]	valid_0's binary_logloss: 0.198244
# [671]	valid_0's binary_logloss: 0.198244
# [672]	valid_0's binary_logloss: 0.198244
# [673]	valid_0's binary_logloss: 0.198244
# [674]	valid_0's binary_logloss: 0.198244
# [675]	valid_0's binary_logloss: 0.198244
# [676]	valid_0's binary_logloss: 0.198244
# [677]	valid_0's binary_logloss: 0.198244
# [678]	valid_0's binary_logloss: 0.198244
# [679]	valid_0's binary_logloss: 0.198244
# [680]	valid_0's binary_logloss: 0.198244
# [681]	valid_0's binary_logloss: 0.198244
# [682]	valid_0's binary_logloss: 0.198244
# [683]	valid_0's binary_logloss: 0.198244
# [684]	valid_0's binary_logloss: 0.198244
# [685]	valid_0's binary_logloss: 0.198244
# [686]	valid_0's binary_logloss: 0.198244
# [687]	valid_0's binary_logloss: 0.198244
# [688]	valid_0's binary_logloss: 0.198244
# [689]	valid_0's binary_logloss: 0.198244
# [690]	valid_0's binary_logloss: 0.198244
# [691]	valid_0's binary_logloss: 0.198244
# [692]	valid_0's binary_logloss: 0.198244
# [693]	valid_0's binary_logloss: 0.198244
# [694]	valid_0's binary_logloss: 0.198244
# [695]	valid_0's binary_logloss: 0.198244
# [696]	valid_0's binary_logloss: 0.198244
# [697]	valid_0's binary_logloss: 0.198244
# [698]	valid_0's binary_logloss: 0.198244
# [699]	valid_0's binary_logloss: 0.198244
# [700]	valid_0's binary_logloss: 0.198244
# [701]	valid_0's binary_logloss: 0.198244
# [702]	valid_0's binary_logloss: 0.198244
# [703]	valid_0's binary_logloss: 0.198244
# [704]	valid_0's binary_logloss: 0.198244
# [705]	valid_0's binary_logloss: 0.198244
# [706]	valid_0's binary_logloss: 0.198244
# [707]	valid_0's binary_logloss: 0.198244
# [708]	valid_0's binary_logloss: 0.198244
# [709]	valid_0's binary_logloss: 0.198244
# [710]	valid_0's binary_logloss: 0.198244
# [711]	valid_0's binary_logloss: 0.198244
# [712]	valid_0's binary_logloss: 0.198244
# [713]	valid_0's binary_logloss: 0.198244
# [714]	valid_0's binary_logloss: 0.198244
# [715]	valid_0's binary_logloss: 0.198244
# [716]	valid_0's binary_logloss: 0.198244
# [717]	valid_0's binary_logloss: 0.198244
# [718]	valid_0's binary_logloss: 0.198244
# [719]	valid_0's binary_logloss: 0.198244
# [720]	valid_0's binary_logloss: 0.198244
# [721]	valid_0's binary_logloss: 0.198244
# [722]	valid_0's binary_logloss: 0.198244
# [723]	valid_0's binary_logloss: 0.198244
# [724]	valid_0's binary_logloss: 0.198244
# [725]	valid_0's binary_logloss: 0.198244
# [726]	valid_0's binary_logloss: 0.198244
# [727]	valid_0's binary_logloss: 0.198244
# [728]	valid_0's binary_logloss: 0.198244
# [729]	valid_0's binary_logloss: 0.198244
# [730]	valid_0's binary_logloss: 0.198244
# [731]	valid_0's binary_logloss: 0.198244
# [732]	valid_0's binary_logloss: 0.198244
# [733]	valid_0's binary_logloss: 0.198244
# [734]	valid_0's binary_logloss: 0.198244
# [735]	valid_0's binary_logloss: 0.198244
# [736]	valid_0's binary_logloss: 0.198244
# [737]	valid_0's binary_logloss: 0.198244
# [738]	valid_0's binary_logloss: 0.198244
# [739]	valid_0's binary_logloss: 0.198244
# [740]	valid_0's binary_logloss: 0.198244
# [741]	valid_0's binary_logloss: 0.198244
# [742]	valid_0's binary_logloss: 0.198244
# [743]	valid_0's binary_logloss: 0.198244
# [744]	valid_0's binary_logloss: 0.198244
# [745]	valid_0's binary_logloss: 0.198244
# [746]	valid_0's binary_logloss: 0.198244
# [747]	valid_0's binary_logloss: 0.198244
# [748]	valid_0's binary_logloss: 0.198244
# [749]	valid_0's binary_logloss: 0.198244
# [750]	valid_0's binary_logloss: 0.198244
# [751]	valid_0's binary_logloss: 0.198244
# [752]	valid_0's binary_logloss: 0.198244
# [753]	valid_0's binary_logloss: 0.198244
# [754]	valid_0's binary_logloss: 0.198244
# [755]	valid_0's binary_logloss: 0.198244
# [756]	valid_0's binary_logloss: 0.198244
# [757]	valid_0's binary_logloss: 0.198244
# [758]	valid_0's binary_logloss: 0.198244
# [759]	valid_0's binary_logloss: 0.198244
# [760]	valid_0's binary_logloss: 0.198244
# [761]	valid_0's binary_logloss: 0.198244
# [762]	valid_0's binary_logloss: 0.198244
# [763]	valid_0's binary_logloss: 0.198244
# [764]	valid_0's binary_logloss: 0.198244
# [765]	valid_0's binary_logloss: 0.198244
# [766]	valid_0's binary_logloss: 0.198244
# [767]	valid_0's binary_logloss: 0.198244
# [768]	valid_0's binary_logloss: 0.198244
# [769]	valid_0's binary_logloss: 0.198244
# [770]	valid_0's binary_logloss: 0.198244
# [771]	valid_0's binary_logloss: 0.198244
# [772]	valid_0's binary_logloss: 0.198244
# [773]	valid_0's binary_logloss: 0.198244
# [774]	valid_0's binary_logloss: 0.198244
# [775]	valid_0's binary_logloss: 0.198244
# [776]	valid_0's binary_logloss: 0.198244
# [777]	valid_0's binary_logloss: 0.198244
# [778]	valid_0's binary_logloss: 0.198244
# [779]	valid_0's binary_logloss: 0.198244
# [780]	valid_0's binary_logloss: 0.198244
# [781]	valid_0's binary_logloss: 0.198244
# [782]	valid_0's binary_logloss: 0.198244
# [783]	valid_0's binary_logloss: 0.198244
# [784]	valid_0's binary_logloss: 0.198244
# [785]	valid_0's binary_logloss: 0.198244
# [786]	valid_0's binary_logloss: 0.198244
# [787]	valid_0's binary_logloss: 0.198244
# [788]	valid_0's binary_logloss: 0.198244
# [789]	valid_0's binary_logloss: 0.198244
# [790]	valid_0's binary_logloss: 0.198244
# [791]	valid_0's binary_logloss: 0.198244
# [792]	valid_0's binary_logloss: 0.198244
# [793]	valid_0's binary_logloss: 0.198244
# [794]	valid_0's binary_logloss: 0.198244
# [795]	valid_0's binary_logloss: 0.198244
# [796]	valid_0's binary_logloss: 0.198244
# [797]	valid_0's binary_logloss: 0.198244
# [798]	valid_0's binary_logloss: 0.198244
# [799]	valid_0's binary_logloss: 0.198244
# [800]	valid_0's binary_logloss: 0.198244
# [801]	valid_0's binary_logloss: 0.198244
# [802]	valid_0's binary_logloss: 0.198244
# [803]	valid_0's binary_logloss: 0.198244
# [804]	valid_0's binary_logloss: 0.198244
# [805]	valid_0's binary_logloss: 0.198244
# [806]	valid_0's binary_logloss: 0.198244
# [807]	valid_0's binary_logloss: 0.198244
# [808]	valid_0's binary_logloss: 0.198244
# [809]	valid_0's binary_logloss: 0.198244
# [810]	valid_0's binary_logloss: 0.198244
# [811]	valid_0's binary_logloss: 0.198244
# [812]	valid_0's binary_logloss: 0.198244
# [813]	valid_0's binary_logloss: 0.198244
# [814]	valid_0's binary_logloss: 0.198244
# [815]	valid_0's binary_logloss: 0.198244
# [816]	valid_0's binary_logloss: 0.198244
# [817]	valid_0's binary_logloss: 0.198244
# [818]	valid_0's binary_logloss: 0.198244
# [819]	valid_0's binary_logloss: 0.198244
# [820]	valid_0's binary_logloss: 0.198244
# [821]	valid_0's binary_logloss: 0.198244
# [822]	valid_0's binary_logloss: 0.198244
# [823]	valid_0's binary_logloss: 0.198244
# [824]	valid_0's binary_logloss: 0.198244
# [825]	valid_0's binary_logloss: 0.198244
# [826]	valid_0's binary_logloss: 0.198244
# [827]	valid_0's binary_logloss: 0.198244
# [828]	valid_0's binary_logloss: 0.198244
# [829]	valid_0's binary_logloss: 0.198244
# [830]	valid_0's binary_logloss: 0.198244
# [831]	valid_0's binary_logloss: 0.198244
# [832]	valid_0's binary_logloss: 0.198244
# [833]	valid_0's binary_logloss: 0.198244
# [834]	valid_0's binary_logloss: 0.198244
# [835]	valid_0's binary_logloss: 0.198244
# [836]	valid_0's binary_logloss: 0.198244
# [837]	valid_0's binary_logloss: 0.198244
# [838]	valid_0's binary_logloss: 0.198244
# [839]	valid_0's binary_logloss: 0.198244
# [840]	valid_0's binary_logloss: 0.198244
# [841]	valid_0's binary_logloss: 0.198244
# [842]	valid_0's binary_logloss: 0.198244
# [843]	valid_0's binary_logloss: 0.198244
# [844]	valid_0's binary_logloss: 0.198244
# [845]	valid_0's binary_logloss: 0.198244
# [846]	valid_0's binary_logloss: 0.198244
# [847]	valid_0's binary_logloss: 0.198244
# [848]	valid_0's binary_logloss: 0.198244
# [849]	valid_0's binary_logloss: 0.198244
# [850]	valid_0's binary_logloss: 0.198244
# [851]	valid_0's binary_logloss: 0.198244
# [852]	valid_0's binary_logloss: 0.198244
# [853]	valid_0's binary_logloss: 0.198244
# [854]	valid_0's binary_logloss: 0.198244
# [855]	valid_0's binary_logloss: 0.198244
# [856]	valid_0's binary_logloss: 0.198244
# [857]	valid_0's binary_logloss: 0.198244
# [858]	valid_0's binary_logloss: 0.198244
# [859]	valid_0's binary_logloss: 0.198244
# [860]	valid_0's binary_logloss: 0.198244
# [861]	valid_0's binary_logloss: 0.198244
# [862]	valid_0's binary_logloss: 0.198244
# [863]	valid_0's binary_logloss: 0.198244
# [864]	valid_0's binary_logloss: 0.198244
# [865]	valid_0's binary_logloss: 0.198244
# [866]	valid_0's binary_logloss: 0.198244
# [867]	valid_0's binary_logloss: 0.198244
# [868]	valid_0's binary_logloss: 0.198244
# [869]	valid_0's binary_logloss: 0.198244
# [870]	valid_0's binary_logloss: 0.198244
# [871]	valid_0's binary_logloss: 0.198244
# [872]	valid_0's binary_logloss: 0.198244
# [873]	valid_0's binary_logloss: 0.198244
# [874]	valid_0's binary_logloss: 0.198244
# [875]	valid_0's binary_logloss: 0.198244
# [876]	valid_0's binary_logloss: 0.198244
# [877]	valid_0's binary_logloss: 0.198244
# [878]	valid_0's binary_logloss: 0.198244
# [879]	valid_0's binary_logloss: 0.198244
# [880]	valid_0's binary_logloss: 0.198244
# [881]	valid_0's binary_logloss: 0.198244
# [882]	valid_0's binary_logloss: 0.198244
# [883]	valid_0's binary_logloss: 0.198244
# [884]	valid_0's binary_logloss: 0.198244
# [885]	valid_0's binary_logloss: 0.198244
# [886]	valid_0's binary_logloss: 0.198244
# [887]	valid_0's binary_logloss: 0.198244
# [888]	valid_0's binary_logloss: 0.198244
# [889]	valid_0's binary_logloss: 0.198244
# [890]	valid_0's binary_logloss: 0.198244
# [891]	valid_0's binary_logloss: 0.198244
# [892]	valid_0's binary_logloss: 0.198244
# [893]	valid_0's binary_logloss: 0.198244
# [894]	valid_0's binary_logloss: 0.198244
# [895]	valid_0's binary_logloss: 0.198244
# [896]	valid_0's binary_logloss: 0.198244
# [897]	valid_0's binary_logloss: 0.198244
# [898]	valid_0's binary_logloss: 0.198244
# [899]	valid_0's binary_logloss: 0.198244
# [900]	valid_0's binary_logloss: 0.198244
# [901]	valid_0's binary_logloss: 0.198244
# [902]	valid_0's binary_logloss: 0.198244
# [903]	valid_0's binary_logloss: 0.198244
# [904]	valid_0's binary_logloss: 0.198244
# [905]	valid_0's binary_logloss: 0.198244
# [906]	valid_0's binary_logloss: 0.198244
# [907]	valid_0's binary_logloss: 0.198244
# [908]	valid_0's binary_logloss: 0.198244
# [909]	valid_0's binary_logloss: 0.198244
# [910]	valid_0's binary_logloss: 0.198244
# [911]	valid_0's binary_logloss: 0.198244
# [912]	valid_0's binary_logloss: 0.198244
# [913]	valid_0's binary_logloss: 0.198244
# [914]	valid_0's binary_logloss: 0.198244
# [915]	valid_0's binary_logloss: 0.198244
# [916]	valid_0's binary_logloss: 0.198244
# [917]	valid_0's binary_logloss: 0.198244
# [918]	valid_0's binary_logloss: 0.198244
# [919]	valid_0's binary_logloss: 0.198244
# [920]	valid_0's binary_logloss: 0.198244
# [921]	valid_0's binary_logloss: 0.198244
# [922]	valid_0's binary_logloss: 0.198244
# [923]	valid_0's binary_logloss: 0.198244
# [924]	valid_0's binary_logloss: 0.198244
# [925]	valid_0's binary_logloss: 0.198244
# [926]	valid_0's binary_logloss: 0.198244
# [927]	valid_0's binary_logloss: 0.198244
# [928]	valid_0's binary_logloss: 0.198244
# [929]	valid_0's binary_logloss: 0.198244
# [930]	valid_0's binary_logloss: 0.198244
# [931]	valid_0's binary_logloss: 0.198244
# [932]	valid_0's binary_logloss: 0.198244
# [933]	valid_0's binary_logloss: 0.198244
# [934]	valid_0's binary_logloss: 0.198244
# [935]	valid_0's binary_logloss: 0.198244
# [936]	valid_0's binary_logloss: 0.198244
# [937]	valid_0's binary_logloss: 0.198244
# [938]	valid_0's binary_logloss: 0.198244
# [939]	valid_0's binary_logloss: 0.198244
# [940]	valid_0's binary_logloss: 0.198244
# [941]	valid_0's binary_logloss: 0.198244
# [942]	valid_0's binary_logloss: 0.198244
# [943]	valid_0's binary_logloss: 0.198244
# [944]	valid_0's binary_logloss: 0.198244
# [945]	valid_0's binary_logloss: 0.198244
# [946]	valid_0's binary_logloss: 0.198244
# [947]	valid_0's binary_logloss: 0.198244
# [948]	valid_0's binary_logloss: 0.198244
# [949]	valid_0's binary_logloss: 0.198244
# [950]	valid_0's binary_logloss: 0.198244
# [951]	valid_0's binary_logloss: 0.198244
# [952]	valid_0's binary_logloss: 0.198244
# [953]	valid_0's binary_logloss: 0.198244
# [954]	valid_0's binary_logloss: 0.198244
# [955]	valid_0's binary_logloss: 0.198244
# [956]	valid_0's binary_logloss: 0.198244
# [957]	valid_0's binary_logloss: 0.198244
# [958]	valid_0's binary_logloss: 0.198244
# [959]	valid_0's binary_logloss: 0.198244
# [960]	valid_0's binary_logloss: 0.198244
# [961]	valid_0's binary_logloss: 0.198244
# [962]	valid_0's binary_logloss: 0.198244
# [963]	valid_0's binary_logloss: 0.198244
# [964]	valid_0's binary_logloss: 0.198244
# [965]	valid_0's binary_logloss: 0.198244
# [966]	valid_0's binary_logloss: 0.198244
# [967]	valid_0's binary_logloss: 0.198244
# [968]	valid_0's binary_logloss: 0.198244
# [969]	valid_0's binary_logloss: 0.198244
# [970]	valid_0's binary_logloss: 0.198244
# [971]	valid_0's binary_logloss: 0.198244
# [972]	valid_0's binary_logloss: 0.198244
# [973]	valid_0's binary_logloss: 0.198244
# [974]	valid_0's binary_logloss: 0.198244
# [975]	valid_0's binary_logloss: 0.198244
# [976]	valid_0's binary_logloss: 0.198244
# [977]	valid_0's binary_logloss: 0.198244
# [978]	valid_0's binary_logloss: 0.198244
# [979]	valid_0's binary_logloss: 0.198244
# [980]	valid_0's binary_logloss: 0.198244
# [981]	valid_0's binary_logloss: 0.198244
# [982]	valid_0's binary_logloss: 0.198244
# [983]	valid_0's binary_logloss: 0.198244
# [984]	valid_0's binary_logloss: 0.198244
# [985]	valid_0's binary_logloss: 0.198244
# [986]	valid_0's binary_logloss: 0.198244
# [987]	valid_0's binary_logloss: 0.198244
# [988]	valid_0's binary_logloss: 0.198244
# [989]	valid_0's binary_logloss: 0.198244
# [990]	valid_0's binary_logloss: 0.198244
# [991]	valid_0's binary_logloss: 0.198244
# [992]	valid_0's binary_logloss: 0.198244
# [993]	valid_0's binary_logloss: 0.198244
# [994]	valid_0's binary_logloss: 0.198244
# [995]	valid_0's binary_logloss: 0.198244
# [996]	valid_0's binary_logloss: 0.198244
# [997]	valid_0's binary_logloss: 0.198244
# [998]	valid_0's binary_logloss: 0.198244
# [999]	valid_0's binary_logloss: 0.198244
# [1000]	valid_0's binary_logloss: 0.198244
# [1001]	valid_0's binary_logloss: 0.198244
# [1002]	valid_0's binary_logloss: 0.198244
# [1003]	valid_0's binary_logloss: 0.198244
# [1004]	valid_0's binary_logloss: 0.198244
# [1005]	valid_0's binary_logloss: 0.198244
# [1006]	valid_0's binary_logloss: 0.198244
# [1007]	valid_0's binary_logloss: 0.198244
# [1008]	valid_0's binary_logloss: 0.198244
# [1009]	valid_0's binary_logloss: 0.198244
# [1010]	valid_0's binary_logloss: 0.198244
# [1011]	valid_0's binary_logloss: 0.198244
# [1012]	valid_0's binary_logloss: 0.198244
# [1013]	valid_0's binary_logloss: 0.198244
# [1014]	valid_0's binary_logloss: 0.198244
# [1015]	valid_0's binary_logloss: 0.198244
# [1016]	valid_0's binary_logloss: 0.198244
# [1017]	valid_0's binary_logloss: 0.198244
# [1018]	valid_0's binary_logloss: 0.198244
# [1019]	valid_0's binary_logloss: 0.198244
# [1020]	valid_0's binary_logloss: 0.198244
# [1021]	valid_0's binary_logloss: 0.198244
# [1022]	valid_0's binary_logloss: 0.198244
# [1023]	valid_0's binary_logloss: 0.198244
# [1024]	valid_0's binary_logloss: 0.198244
# [1025]	valid_0's binary_logloss: 0.198244
# [1026]	valid_0's binary_logloss: 0.198244
# [1027]	valid_0's binary_logloss: 0.198244
# [1028]	valid_0's binary_logloss: 0.198244
# [1029]	valid_0's binary_logloss: 0.198244
# [1030]	valid_0's binary_logloss: 0.198244
# [1031]	valid_0's binary_logloss: 0.198244
# [1032]	valid_0's binary_logloss: 0.198244
# [1033]	valid_0's binary_logloss: 0.198244
# [1034]	valid_0's binary_logloss: 0.198244
# [1035]	valid_0's binary_logloss: 0.198244
# [1036]	valid_0's binary_logloss: 0.198244
# [1037]	valid_0's binary_logloss: 0.198244
# [1038]	valid_0's binary_logloss: 0.198244
# [1039]	valid_0's binary_logloss: 0.198244
# [1040]	valid_0's binary_logloss: 0.198244
# [1041]	valid_0's binary_logloss: 0.198244
# [1042]	valid_0's binary_logloss: 0.198244
# [1043]	valid_0's binary_logloss: 0.198244
# [1044]	valid_0's binary_logloss: 0.198244
# [1045]	valid_0's binary_logloss: 0.198244
# Early stopping, best iteration is:
# [45]	valid_0's binary_logloss: 0.122818
# LGBMClassifier(n_estimators=4000)

# %%
def precision_recall_curve_plot(y_test, pred_proba_c1):
    precisions, recalls, thresholds = precision_recall_curve(y_test, pred_proba_c1)
    
    plt.figure(figsize = (8, 6))
    threshold_boundary = thresholds.shape[0]
    plt.plot(thresholds, precisions[0:threshold_boundary], linestyle = '--', label = 'precision')
    plt.plot(thresholds, recalls[0:threshold_boundary], label = 'recall')
    
    start, end = plt.xlim()
    plt.xticks(np.round(np.arange(start, end, 0.1), 2))
    
    plt.xlabel('Threshold value'); plt.ylabel('Precision and Recall value')
    plt.legend(); plt.grid()
    plt.show()

# %%
precision_recall_curve_plot(y_test, pred_proba_po)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15256/2716455630.py in <module>
# ----> 1 precision_recall_curve_plot(y_test, pred_proba_po)
#
# ~\AppData\Local\Temp/ipykernel_15256/548463133.py in precision_recall_curve_plot(y_test, pred_proba_c1)
#       1 def precision_recall_curve_plot(y_test, pred_proba_c1):
# ----> 2     precisions, recalls, thresholds = precision_recall_curve(y_test, pred_proba_c1)
#       3
#       4     plt.figure(figsize = (8, 6))
#       5     threshold_boundary = thresholds.shape[0]
#
# NameError: name 'precision_recall_curve' is not defined
